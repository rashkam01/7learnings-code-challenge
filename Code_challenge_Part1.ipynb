# %% [markdown]
# # Part 1

# %% [markdown]
# Starting with querying the weather data from google open data sources.
#
# A short descriptiopn of the step taken to connect the Jupyter notbook with GCP and querying
# 1. Enable BigQuery API in GCP
# 2. Google Cloud SDK Setup
# 3. Creating Credentials (Service account)
# 4. Downloading the Service account key as JSON
#  Using following
#  os.environ['GOOGLE_APPLICATION_CREDENTIALS'] ='Path/Key**3542.json'

# %%
# %load_ext google.cloud.bigquery

# %% [markdown]
# ### 20 rows were queried as shown in the example

# %%
# %%bigquery
# SELECT
# *,
# FROM `bigquery-public-data.samples.gsod`
# LIMIT 20
# Out:
#     station_number  wban_number  year  month  day  mean_temp  \
# 0            39730        99999  1929     10   20  52.799999
# 1            33110        99999  1929     12   18  47.500000
# 2            37770        99999  1931      4   24  50.200001
# 3           726810        24131  1931      6   23  65.099998
# 4           726810        24131  1931      3    2  42.799999
# 5           726810        24131  1931      9   17  67.000000
# 6           726810        24131  1931      8    7  68.400002
# 7           726810        24131  1932      7   14  64.099998
# 8           726810        24131  1932     10   23  41.099998
# 9           726810        24131  1932      1    5  24.600000
# 10          726815        24106  1932      8   27  71.000000
# 11          726810        24131  1932      8   20  71.000000
# 12          726810        24131  1932      5   21  55.200001
# 13          370310        99999  1933     10   17  55.299999
# ...

# %% [markdown]
# ## Task 1

# %% [markdown]
# Due to some initial mis-understanding data from 2010 to 2021, was initially queried and stored in a csv. But Later found out to be only consisting of data from 2010.

# %%
# %%bigquery df
# SELECT
# *,
# FROM `bigquery-public-data.samples.gsod`
# WHERE year between 2010 and 2021
# Out:
#          station_number  wban_number  year  month  day  mean_temp  \
# 0                415360        99999  2010      3   29  69.400002
# 1                717970        99999  2010      1   10  18.500000
# 2                 10231        99999  2010      3   16  35.099998
# 3                714090        99999  2010      4   10  33.900002
# 4                414770        99999  2010      4   15  85.900002
# ...                 ...          ...   ...    ...  ...        ...
# 1042809           66720        99999  2010      1    6  30.200001
# 1042810           34050        99999  2010      4   13  47.500000
# 1042811           66720        99999  2010      1   21  33.299999
# 1042812           22470        99999  2010      1    1  13.200000
# 1042813           31530        99999  2010      1   28  40.500000
#
#          num_mean_temp_samples  mean_dew_point  num_mean_dew_point_samples  \
# 0                            4       44.000000                         4.0
# ...

# %%
df.shape
# Out:
# (1042814, 31)

# %%
import pandas as pd

# %%
df.to_csv('weather_pred', sep='\t', encoding='utf-8')

# %%
df.to_csv('weather_pred_01.csv', sep='\t', encoding='utf-8')

# %%
df = pd.read_csv('weather_pred_01.csv', sep='\t' , encoding='utf-8')

# %%
#df.head(20)

# %% [markdown]
# ### 1. Task

# %% [markdown]
# Change the date format to 'YYYY-MM-DD' and select the data from 2006 till 2010 for station numbers including and between 725300 and 726300 , and save it as a pandas dataframe. Note the maximum year available is 2010.

# %%
# Query run in GCP BiqQuery console to obtain the correct output
SELECT DATE(year, month, day) as date_formatted, * EXCEPT (year, month, day)
FROM `bigquery-public-data.samples.gsod`
WHERE year between 2006 and 2010 AND station_number between 725300 and 726300
# Out:
#   File "<ipython-input-19-a854c38fcf71>", line 1
#     SELECT DATE(year, month, day) as date_formatted, * EXCEPT (year, month, day)
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# This query will process 16.1 GiB when run.

# %% [markdown]
# This is the solution for Task1 - Due to lack of time, proceded to modelling PART 2 Using the data already provided in the task. However, the following query when run in BigQuery GCP console provided with the data from 2006 till 2010 for station numbers including and between 725300 and 726300. The above part also shows how it was transformed into pandas dataframe and also how to save in csv locally if needed.
